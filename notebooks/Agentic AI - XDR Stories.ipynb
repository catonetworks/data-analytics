# %% [markdown]
# ## Agentic AI - XDR Stories
#
# <div style="background-color: #FFEBCC; border-left: 6px solid #FFA500; padding: 10px;">
# <b>Warning:</b>This example requires the use of a third party, commercial LLM (OpenAI) which charges for API use. The XDR incident data being sent to OpenAI can be substantial and will often include sensitive data such as PII. Anyone seeking to build an agent using the process described below should ensure that they are willing to pay the charges associated with use of the LLM, and have approval to send their account data to OpenAI. Alternative models and platforms are available which might be cheaper and/or allow customers to run a model locally.
# </div>
#
# ### What do we mean by "Agentic AI"?
#
# According to ChatGPT:
#
# ```
# Agentic AI refers to artificial intelligence systems that operate autonomously, making decisions and taking actions to achieve specific goals without constant human intervention.
# ```
#
# The key factors which distinguish an AI Agent from a non-AI agent (such as a reminder email your mobile phone provider sends you when you are running low on credit) and which distinguish it from non-agentic AI (such as a ChatGPT conversation) are:
# * **Autonomous Decision-Making:** the system can make decisions on unfamiliar data without ongoing explanation and assistance from a human.
# * **Independent Execution:** the system operates when required without needing a human to activate it. This might be in response to some sort of event trigger, or a regular poll.
# * **Stimulus/response:** the system receives input from some external factors, and executes actions accordingly.
#
# In this example we will build a simple agent which manages a Cato Networks customer account's XDR incident feed, by providing analyst feedback for open stories. In order to be able to do this, it will:
#
# 1. Use the Cato API to download a list of stories generated or updated during a certain timeframe.
# 2. Use the OpenAI API to send each story together with a suitable prompt, receiving the model's classification of the incident and recommended settings for fields such as status and verdict.
# 3. Format the model's response as Cato XDR analyst feedback and submit via the Cato API, checking for any errors.
#
# The value proposition is clear. Even though the Cato Networks XDR feature provides a low-volume, high-value feed of curated security events, if you are a small IT team, you might not have time to manage your XDR story workbench as often or as diligently as you would like. Even if you have the resources, you might appreciate having a knowledgeable and capable LLM triage the list for you, closing out incidents which do not meet the criteria for involvement by a human analyst. You may even find over time that you place a high degree of trust in the AI's capabilities to make good quality decisions, 24x7x365.
#
# ### Cato Networks XDR
#
# ```
# XDR (Extended Detection and Response) is a comprehensive cybersecurity approach that integrates and correlates data from multiple security layers to provide enhanced threat detection, investigation, and response capabilities.
#
# Cato Networks' XDR platform enables both Security operations and Network operations teams to monitor the organization's network for potential security threats and network performance issues. The platform includes advanced correlation engines (called Producers) that analyze traffic data to find matches for specific indications of threat activities or network issues. When a match is found, it produces a story that can be reviewed and investigated in the Cato Management Application (CMA).
# ```
#
# That's the perfectly acceptable definition I received from the Cato Chatbot. Cato's XDR is a popular feature which adds an additional tier to the value pyramid:
#
# <div style="text-align: center;"><img src="valuevolume.png" width="600"></div>
#
# At the bottom of the pyramid are firewall events from Cato's Triple Firewall (Internet/WAN/LAN) which can be up to 90% of a Cato customer's feed. Although these are valuable from a forensic and incident response perspective, when it comes to threat hunting the large volume outweighs the value considerably. Next up are the events produced by Cato security features such as IPS, Anti Malware, CASB, DLP, as well as connectivity events such as ZTNA user connections and CMA logins. These are a much lower volume but much higher value. Finally at the top are the XDR producer models running over everything happening in the bottom tiers, producing a low volume of extremely high value, curated stories. We're going to add a new tier on top of the pyramid, so the human analyst working the list of open stories can focus on those stories which are most worthy of attention, such as incidents where not all activity was blocked.
#
# **Our goal is to close low-severity stories while adding additional explanatory information to more interesting stories in the XDR workbench in CMA**.
#
#
# ### Initialising the connection to the API.
# Firstly, let's import the libraries we need and set up the connection to the API. As usual, we assuming that the account ID and API key are preloaded as environment variables and we use our helper module to encapsulate the business of making an API call (see the [Getting Started](Getting%20Started.ipynb) notebook if any of this is unclear):

# %%
#
# Initialise the API connection
#
import datetime
import json
import os
from collections import defaultdict
from openai import OpenAI
from cato import API
C = API(os.environ["CATO_API_KEY"])

# %% [markdown]
# ### The XDR Stories Query
#
# The Cato Networks API call our agent will use to retrieve XDR stories is the [xdr.stories](https://api.catonetworks.com/documentation/#query-xdr.stories) query, which is documented in the knowledge base. XDR stories are **rich*** objects with multiple levels, many different fields and potentially large arrays of incident and timeseries data. A full explanation of every single field is outside the scope of this document and potentially any document, due to the dynamic nature of XDR in general, and the rate at which Cato introduces new fields and features. This is one of the primary advantages of using an LLM to analyse the story data:
#
# **The AI should be able to understand the data without being told exactly what it is.**
#
# This is possible because the Cato API provides fields which describe what they actually contain; for example, the object which contains the incident data is called, well, **incident**. We do however have to construct a GraphQL query which the agent will use to extract all these fields. When I need to construct a new query, especially where there are many potential fields, a method I've found to be useful is:
#
# 1. Copy the example query and variables from the Cato API documentation: [https://api.catonetworks.com/documentation/#query-xdr.stories](https://api.catonetworks.com/documentation/#query-xdr.stories)
# 2. Paste these into the Cato API Playground: [https://api.catonetworks.com/api/v1/graphql2](https://api.catonetworks.com/api/v1/graphql2)
# 3. Adjust the query, adding fields as suggested by the documentation and according to the online help provided by the Playground.
# 4. Copy the finished query and variables into your code.
#
# This process resulted in the following query and variables:

# %%
#
# Query
#
query = '''query Stories($accountId: ID!, $from: Int!, $limit: Int!, $sort: [StorySortInput!], $filter: [StoryFilterInput!]!) {
  xdr(accountID: $accountId) {
    stories(
      input: {paging: {from: $from, limit: $limit}, sort: $sort, filter: $filter}
    ) {
      paging {
        from
        limit
        total
      }
      items {
        ...StoryBrief
      }
    }
  }
}

fragment StoryBrief on Story {
  id
  accountId
  accountName
  updatedAt
  createdAt
  analystName
  incident {
    analystFeedback {
      additionalInfo
      severity
      threatType {
        name
        recommendedAction
        details
      }
      threatClassification
      verdict
    }
    connectionType
    criticality
    description
    engineType
    firstSignal
    id
    indication
    lastSignal
    predictedVerdict
    predictedThreatType
    producerName
    queryName
    research
    site {
      id
      name
    }
    source
    sourceIp
    status
    storyDuration
    ticket
    user {
      id
      name
    }
    vendor    
    ... on Threat {
      ...ThreatIncidentBrief
    }
    ... on ThreatPrevention {
      ...ThreatPreventionIncidentBrief
    }
    ... on AnomalyStats {
    ...AnomalyStatsIncidentBrief
    }
    ... on AnomalyEvents {
      ...AnomalyEventsIncidentBrief
    }
  }
}

fragment ThreatIncidentBrief on Threat {
  site {
    id
    name
  }
  user {
    id
    name
  }
  direction
}

fragment ThreatPreventionIncidentBrief on ThreatPrevention {
  clientClass
  deviceName
  direction
  events {
    action
    appId
    appName
    dnsProtectionCategory
    eventType
    ruleId
    scanResult
    severity
    signatureId
    threatName
    threatType
    virusName
  }
  flowsCardinality
  logonName
  macAddress
  mitres {
    id
    name
  }
  os
  riskLevel
  similarStoriesData {
    indication
    similarityPercentage
    storyId
    threatClassification
    threatTypeName
    verdict
  }
  targets {
    analysisScore
    categories
    catoPopularity
    countryOfRegistration
    creationTime
    engines
    eventData {
      action
      appId
      appName
      dnsProtectionCategory
      eventType
      ruleId
      scanResult
      severity
      signatureId
      threatName
      threatType
      virusName
    }
    infectionSource
    name
    searchHits
    threatFeeds
    threatReference
    type
  }
  threatPreventionsEvents {
    appName
    clientClass
    createdAt
    destinationCountry
    destinationGeolocation
    destinationIp
    destinationPort
    direction
    dnsResponseIP
    domain
    fileHash
    httpResponseCode
    ja3
    method
    referrer
    smbFileName
    sourceGeolocation
    sourceIp
    sourcePort
    target
    tunnelGeolocation
    url
    user
    userAgent
  }
  ticket
}

fragment AnomalyStatsIncidentBrief on AnomalyStats {
  clientClass
  deviceName
  direction
  logonName
  macAddress
  mitres {
    id
    name
  }
  os
  similarStoriesData {
    indication
    similarityPercentage
    storyId
    threatClassification
    threatTypeName
    verdict
  }
  targets {
    analysisScore
    categories
    catoPopularity
    countryOfRegistration
    creationTime
    engines
    eventData {
      action
      appId
      appName
      dnsProtectionCategory
      eventType
      ruleId
      scanResult
      severity
      signatureId
      threatName
      threatType
      virusName
    }
    infectionSource
    name
    searchHits
    threatFeeds
    threatReference
    type
  }
  ticket
}

fragment AnomalyEventsIncidentBrief on AnomalyEvents {
  clientClass
  deviceName
  direction
  logonName
  macAddress
  mitres {
    id
    name
  }
  os
  similarStoriesData {
    indication
    similarityPercentage
    storyId
    threatClassification
    threatTypeName
    verdict
  }
  targets {
    analysisScore
    categories
    catoPopularity
    countryOfRegistration
    creationTime
    engines
    eventData {
      action
      appId
      appName
      dnsProtectionCategory
      eventType
      ruleId
      scanResult
      severity
      signatureId
      threatName
      threatType
      virusName
    }
    infectionSource
    name
    searchHits
    threatFeeds
    threatReference
    type
  }
  ticket
}
'''

#
# Variables
#
variables = {
  "accountId": os.environ["CATO_ACCOUNT_ID"],
  "from": 0,
  "limit": 25,
  "filter": [
    {
      "timeFrame": {"time": "last.P1D", "timeFrameModifier": "StoryUpdate"},
      "producer": {"not_in": ["NetworkXDR", "NetworkMonitor"]}
    }
  ],
  "sort": [{"fieldName": "updatedAt", "order": "desc"}]
}

# %% [markdown]
# ### Step 1: Downloading the XDR stories
#
# Now that we have imported our modules and defined the Cato API query for downloading stories, the agent can call this query and store the results in a list of story objects. It needs to do this in a loop because the XDR query is limited by a batch size, and so allows the requester to paginate over multiple iterations to retrieve all eligible stories according to the input parameters. These parameters include a timeframe, and for the purposes of this exercise, we will use a timeframe of 1 day. This implies that the agent will be scheduled to only execute once every 24 hours. For some organisations this is entirely acceptable; others might prefer an agent which runs more frequently, such as once per hour, in which case the timeframe input would need to be aligned with this schedule.
#
# After each iteration we print the number of stories retrieved in the current batch, the total number saved to our list of stories, and the total number eligible for retrieval, stopping when a batch returns zero stories:

# %%
#
# Define an object to hold the stories
#
stories = []


#
# Iterate over the query until we have the total
#
iteration = 0
while True:

    
    #
    # Make the query
    #
    iteration += 1
    variables["from"] = len(stories)
    success, result = C.send("Stories", variables, query)
    items = result["data"]["xdr"]["stories"]["items"]
    line = f'iteration:{iteration} len(items):{len(items)} len(stories):{len(stories)} '
    line += f'total:{result["data"]["xdr"]["stories"]["paging"]["total"]}'
    print(line)


    #
    # Collect the stories
    #
    for story in items:
        stories.append(story)


    #
    # Stop if we received zero
    #
    if len(items) == 0:
        print("Received zero, stopping")
        break
# Out:
# iteration:1 len(items):25 len(stories):0 total:71
# iteration:2 len(items):25 len(stories):25 total:71
# iteration:3 len(items):21 len(stories):50 total:71
# iteration:4 len(items):0 len(stories):71 total:71
# Received zero, stopping

# %% [markdown]
# ### Step 2: Submitting the stories to the LLM
#
# This step can be divided into two parts: defining a function to submit the story together with an appropriate system prompt, and then iterating over the stories we downloaded in step 1, submitting the story and saving the feedback.
#
# The system prompt below does the following things:
# * Provides a basic description of the goal. Note that we don't provide any information on the structure of the data to be inputted. We don't even tell the LLM that it is in JSON format.
# * Describes in detail that the **response** should be in JSON format, what those JSON fields should be and, where the field comes from an enum, list what those allowed enum values are.
# * Includes some advice for how certain incidents should be handled, such as that low severity incidents can be closed.
# * Specifies that the model provide an explanation for why it made the decisions it did, as an additional field.
#
# What advice should be provided to the LLM depends very much on the requirements of the organisation. The below is just an example.

# %%
#
# Define a function to call the LLM
#
def get_llm_recommendation(story):
    openai = OpenAI(api_key=os.environ["OPENAI"])
    system_prompt = """You are an agent which acts as a security analyst, evaluating XDR incident data from a SASE provider, 
responding with recommendations for how the incident should be handled.

The response will be a JSON object in this format:
{
    "additionalInfo": "Free text for the analyst to enter additional information about the XDR story",
    "severity": "String from a fixed list of predefined values, for analyst to assign the severity of a Malicious XDR story",
    "status": "String from a fixed list of predefined values, for the current status of the XDR story",
    "threatClassification": "Brief classification of the threat no more than 5 words.",
    "threatType": {
        "details": "Free text to provide more information on the type of threat",
        "name": "Free text to provide a short, descriptive name for the threat",
        "recommendedAction": "Free text to provide suggestions for how the threat should be handled"
    }
    "verdict": "String from a fixed list of predefined values, for the analyst to assign the verdict of the XDR story"
    "explanation": "Free text field where you explain your reasoning for the severity, status and verdict"
}

Severity values are:
["High", "Medium", "Low"]

Status values are:
["Closed","Monitoring","PendingAnalysis","PendingMoreInfo"]

Verdict values are:
["Benign","Informational","Malicious","Suspicious"]

Low severity incidents should have status=Closed. 
Medium severity incidents where all actions were blocked should have status=Closed.
Incidents where all actions were blocked should have status=Closed.
Network scanning is a low severity incident.
Suspicious incidents should have status=Closed if there is no malicious activity.
    """
    user_prompt = json.dumps(story)
    response = openai.chat.completions.create(
        model = "gpt-4o",
        messages = [
            {"role":"system", "content": system_prompt},
            {"role":"user", "content": user_prompt}
        ],
        response_format={"type":"json_object"}
    )
    return json.loads(response.choices[0].message.content)

# %% [markdown]
# Having defined our function including the system prompt, the agent can now loop over the stories, submitting each one, and recording the feedback. We'll print a short line of output each time to see the decision and explanation.

# %%
#
# Iterate over the stories, asking for an LLM recommendation for each one
#
results = {}
statuses = defaultdict(lambda:0)
for i, story in enumerate(stories):
    if story["incident"]["status"] != "Closed":

        #
        # Make the submission and get the result
        #
        result = get_llm_recommendation(story)

        #
        # Skip any where we didn't get the right fields
        #
        fields = ["status", "severity", "verdict", "explanation", "threatClassification", "threatType"]
        if not all([F in result for F in fields]):
            print(f'MISSING FIELD: {fields-result.keys()}')
            continue
                

        #
        # Log the result
        #
        results[story["id"]] = result            
        statuses[result["status"]] += 1
        line = f'{i+1}/{len(stories)} id:{story["id"]} status:{story["incident"]["status"]}->{result["status"]} '
        line += f'criticality:{story["incident"]["criticality"]}->{result["severity"]} '
        line += f'verdict:{story["incident"]["predictedVerdict"]}->{result["verdict"]}'
        line += f'\nexplanation:{result["explanation"]}\n'
        print(line)

#
# Primt summary
#
for status, count in statuses.items():
    print(f'{status}:{count}')
# Out:
# 1/71 id:66c08a7427f1a81d2bf5080b status:Open->PendingAnalysis criticality:3->High verdict:None->Suspicious
# explanation:The connection to a low-reputation domain using a scripting language over HTTP could suggest an attempted command and control communication. This suspicious behavior, combined with the use of a scripting language, often reflects malicious intent, necessitating further investigation to determine the true nature of the activity. Given the potential for misuse, the severity is considered high and the status is set to pending analysis as more detail is required to ascertain the intent definitively.
#
# 2/71 id:66b04dd163405215b7ddd526 status:Open->PendingAnalysis criticality:3->Medium verdict:None->Suspicious
# explanation:Given the nature of the behavior—HTTP communication using a scripting language to a low-popularity domain—there is a high suspicion of this being preparatory or active malware-related activity. The severity is marked as Medium due to the potential seriousness, but more information and context are needed to identify any actual compromise or significant risk, thus the status is PendingAnalysis. This needs further investigation to determine whether it is malicious or a false positive.
#
# 3/71 id:67c4271e28943b55b76a09c1 status:Open->PendingAnalysis criticality:6->Medium verdict:None->Suspicious
# explanation:The incident's communication pattern with low-reputation URLs is suspicious and needs further investigation to determine if there is any malicious intent or behavior. Since not all actions were blocked, it requires the attention of an analyst to ensure that any potential threat is mitigated.
#
# 4/71 id:67c4270b28943b55b76a09b1 status:Open->Monitoring criticality:6->Medium verdict:None->Suspicious
# explanation:The activity is suspicious due to the nature of communication with URLs flagged for low reputations by threat intelligence. However, the lack of additional evidence of active exploitation or confirmed malicious behavior means that the severity is Medium. Monitoring is recommended to detect if further actions or patterns of behavior emerge indicating an increase in threat level.
#
# 5/71 id:67c426e028943b55b76a09a0 status:Open->PendingAnalysis criticality:9->Medium verdict:None->Suspicious
# explanation:The incident is classified as medium severity due to the potential risk associated with communication to low-reputation URLs, which can signify malicious intentions. The status is set to PendingAnalysis to gather more information and confirm the absence or presence of harmful activities. The verdict is Suspicious, as the activities warrant a more detailed investigation to verify their nature and intent.
#
# 6/71 id:67c4279d28943b55b76a0a44 status:Open->Closed criticality:6->Medium verdict:None->Malicious
# explanation:The communication with low-reputation URLs often indicates deliberate malicious activity, especially if the URLs are tied to known threat campaigns. Due to the nature of this incident, and despite the lack of noted direct harm, the reputation of the URLs suggests the incident could pose a threat if such communications continue unchecked. Therefore, a Medium severity and Closed status are appropriate, as further action is unnecessary without new indications or direct incidences of compromise.
#
# 7/71 id:67c4278f28943b55b76a0a32 status:Open->PendingAnalysis criticality:9->Medium verdict:None->Suspicious
# explanation:Communication with low-reputation URLs suggests potentially harmful intent, but there is currently no definitive indication that a compromise has occurred. Given potential risk, but without concrete evidence of malicious activity or compromise, this incident has been classified as 'Medium' severity pending further analysis. Status is kept as 'PendingAnalysis' to allow for further investigations and collection of additional data on the reputation and intent of URLs involved.
#
# 8/71 id:67c46a11ddfded5aa324a789 status:Open->Closed criticality:8->Medium verdict:None->Suspicious
# explanation:The activity is considered suspicious due to the involvement with low-reputation URLs, which are often linked with malicious activities as per threat intelligence feeds. However, no evidence points to actual malicious actions. Given the situation, Medium severity is assigned, and since no potentially harmful activity was executed (only suspicious network behavior), the status is set to Closed after blocking actions or securing the environment.
#
# 10/71 id:67c427c028943b55b76a0a7f status:Open->Closed criticality:5->Medium verdict:None->Suspicious
# explanation:The severity is marked as Medium due to the interaction with potentially malicious URLs, which indicates an elevated risk. However, the status is Closed because the investigation into this specific incident should be concluded unless further malicious activity is detected. Communications with suspicious URLs can often be benign, such as false positives or URLs with outdated reputations. Recommended actions include verification of user activity, network monitoring, and re-assessment of URL blocking policies.
#
# 11/71 id:67c4271428943b55b76a09b9 status:Open->Closed criticality:6->Medium verdict:None->Suspicious
# explanation:The activity is marked as suspicious due to communication with potentially dangerous URLs and carries a medium severity level because it can lead to potential security risks. Despite its suspicious nature, there are no indications of active malicious behavior. Therefore, the status is set to Closed, since systems appear to have prevented any escalation.
#
# 12/71 id:67c4275428943b55b76a09e9 status:Open->Monitoring criticality:9->Medium verdict:None->Suspicious
# explanation:This incident was flagged due to communication with low-reputation URLs. Such URLs are indicators of potentially malicious activities such as phishing, malware distribution, or command and control (C2) operations. The absence of concrete malicious activity downgrades the severity from High to Medium. Monitoring the incident is recommended to catch any developments or recurring connections which may elevate the risk assessment.
#
# 13/71 id:67c4273828943b55b76a09d5 status:Open->Closed criticality:8->Medium verdict:None->Suspicious
# explanation:The incident involves communication with low-reputation URLs, which is marked as suspicious due to potential risks of phishing or malware. However, without evidence of malicious activity (such as data exfiltration or system compromise), the severity is medium and the incident can be closed after ensuring no further harmful interactions occur.
#
# 14/71 id:67c41b9628943b55b76a033b status:Open->Closed criticality:9->Medium verdict:None->Malicious
# explanation:The incident indicates that hosts in the network are communicating with known malicious domains, classifying it as a sign of potential malware activity. Given the nature of the detected activity, a medium severity rating is appropriate. However, assuming all actions were blocked, closing the status is suitable. The verdict is 'Malicious' due to the involvement of malicious domains.
#
# 15/71 id:6565ad05f916b2799c1790b6 status:Open->Closed criticality:1->Low verdict:None->Benign
# explanation:Network scanning is a common reconnaissance activity and is considered low severity due to its non-destructive nature. All scanning attempts were effectively blocked by IPS signatures, reducing the risk and allowing for the incident to be closed with a benign verdict. Continued monitoring and updating IPS rules are recommended to maintain security.
#
# 16/71 id:67c41f1528943b55b76a0668 status:Open->PendingAnalysis criticality:9->High verdict:None->Malicious
# explanation:The incident is rated high severity due to the direct communication with known malicious domains, suggesting possible malware control or data exfiltration activity. The status is set to PendingAnalysis as immediate action and investigation are necessary to confirm and mitigate potential breach or malware presence. It is tagged as a malicious activity, since the domains communicated with are known to be harmful, regardless of no direct phishing activity being detected.
#
# 17/71 id:6565ad04f916b2799c1790b4 status:Open->Closed criticality:1->Low verdict:None->Informational
# explanation:Network scanning attempts like SYN scans are typically of low severity because they do not directly cause damage. In this case, all attempts were blocked by security systems, indicating that no penetration or exploitation occurred. It is primarily an informational event, confirming that the threat prevention measures are effective.
#
# 18/71 id:6565acf6f916b2799c179099 status:Open->Closed criticality:1->Low verdict:None->Informational
# explanation:Network scanning incidents are typically of low severity if effectively blocked by network security. In this case, all activities identified as potential scans were blocked, indicating there was no breach in security. Thus, the incident is rated as informational and closed. Keeping security measures updated will ensure continued protection against such threats.
#
# 19/71 id:6565acfef916b2799c1790a8 status:Open->Closed criticality:1->Low verdict:None->Benign
# explanation:The incident is classified as low severity since network scanning by itself doesn't result in a direct compromise, particularly when all scanning activities were blocked. Considering that all detected scanning patterns from the source IP were blocked and contained by the network's defenses, the incident does not show signs of progression to a more severe threat. Therefore, the verdict is benign and the incident status is closed, acknowledging the effectiveness of the current threat prevention measures.
#
# 20/71 id:6565ad00f916b2799c1790ab status:PendingMoreInfo->Closed criticality:1->Low verdict:None->Informational
# explanation:The incident was classified as low severity because it involved network scanning attempts, which were blocked effectively by the security mechanisms in place. The status is closed due to the absence of further malicious activity, and the informational verdict is given since no harm was done.
#
# 21/71 id:67c41a4528943b55b76a02b8 status:Open->PendingAnalysis criticality:9->High verdict:None->Malicious
# explanation:The communication with a domain classified as malicious based on threat intelligence suggests a possible malware infection on the host. The incident has a high severity due to the nature of the threat, which may jeopardize network integrity and data security. Action is needed to verify the presence of malware and to mitigate its impact.
#
# 22/71 id:67c41c0328943b55b76a03b3 status:Open->PendingAnalysis criticality:9->High verdict:None->Malicious
# explanation:The incident involves hosts communicating with domains identified as malicious by a threat intelligence feed, suggesting a high risk of malware activity. The severity is rated as High due to the potential impact on the organization's security. PendingAnalysis status is assigned as further investigation is necessary to assess the extent of the threat, and appropriate containment measures need to be implemented.
#
# 23/71 id:67c46345ddfded5aa324a640 status:Open->PendingAnalysis criticality:9->High verdict:None->Malicious
# explanation:The incident describes communication with domains verified as malicious by a threat intelligence feed over HTTP, which is indicative of potential malware activity, not merely suspicious or informational. Given the communication with a known malicious domain, it is vital to perform further analysis to ensure the security of the network. This warrants a high severity due to the potential implications of malware communication, and further investigation is justified to confirm the absence of a broader compromise.
#
# 25/71 id:6565acf9f916b2799c17909c status:Open->Closed criticality:1->Low verdict:None->Informational
# explanation:The incident was classified as low severity due to its nature as a network scanning attempt. Network scanning attempts are often categorized as reconnaissance without direct malicious payloads, particularly when all attempts are blocked at the network level. Given the effective blocking of all scanning attempts, the verdict is considered informational, indicating awareness of the attempts for historical and statistical purposes, rather than an action-worthy threat.
#
# 26/71 id:6565acf6f916b2799c179097 status:Open->Closed criticality:1->Low verdict:None->Benign
# explanation:The network scanning attempt was detected and blocked, minimizing any threat to the network. As such, it presented a low severity and all malicious actions were halted before any further impact could occur. Therefore, closing the incident is appropriate.
#
# 27/71 id:6565ad0ff916b2799c1790cb status:Open->Closed criticality:1->Low verdict:None->Informational
# explanation:This incident is classified as low severity because network scanning, while potentially probing for vulnerabilities, did not result in any compromise. All suspicious activities were successfully blocked, thus mitigating any potential threat. The nature of network scanning inherently carries a lower risk if systems are properly configured to handle such threats.
#
# 28/71 id:6565ad0df916b2799c1790c5 status:Open->Closed criticality:1->Low verdict:None->Benign
# explanation:This incident is classified as a network scan using SYN packets, a typical reconnaissance attack method aimed at mapping network resources. Such activities are considered low severity as they are not a direct threat unless combined with other attacks. Importantly, all detected scanning attempts were effectively blocked by existing security measures (IPS actions were 'Block'), meaning no further action is required beyond monitoring similar activities and ensuring defenses remain robust. Hence, the incident can be closed with a benign verdict due to the absence of any compromise or exploitation beyond mere scanning attempts.
#
# 30/71 id:67c4110228943b55b769fab6 status:Open->PendingAnalysis criticality:9->High verdict:None->Malicious
# explanation:The incident describes a clear case of hosts communicating with domains classified as malicious. Given the nature of the threat intelligence and the malicious verdict, this scenario indicates a high likelihood of compromised systems or malware activity. Immediate action is required to prevent potential data exfiltration or broader network compromise. Therefore, assigning it a high severity and keeping it open for further analysis and resolution tasks is justified.
#
# 31/71 id:65a4f3e482ed673a196f7c14 status:Open->Closed criticality:5->Medium verdict:None->Suspicious
# explanation:The incident involves attempts to download files that are typically associated with malicious activities, such as credential dumping and general malware. The fact that these downloads were blocked by the security measures in place places this incident in the 'Suspicious' category, since no actual harm was done and no systems were compromised. Given that all actions were blocked effectively, the severity is 'Medium' and status 'Closed'.
#
# 32/71 id:65a4f3ec82ed673a196f7c1c status:Open->Closed criticality:4->Medium verdict:None->Malicious
# explanation:The incident was classified as 'Medium' severity due to the aggressive nature of the malware and its potential impact if executed. However, as all malicious download attempts were blocked successfully, there is no immediate threat, justifying the 'Closed' status. The verdict is 'Malicious' because the files attempted to be downloaded are explicitly recognized as malicious by anti-malware solutions.
#
# 33/71 id:65a4f3ce82ed673a196f7bfe status:Open->Closed criticality:6->Medium verdict:None->Suspicious
# explanation:The detection of file downloads tagged as malicious suggests potential malicious intent, however, all activities were blocked effectively by the anti-malware engine. This warrants a Medium severity due to the nature of files involved, but the proper functioning of security controls allows the status to be closed and the verdict to remain suspicious as no actual system compromise occurred.
#
# 34/71 id:65a4f3e082ed673a196f7c12 status:Open->Closed criticality:6->Medium verdict:None->Malicious
# explanation:The assigned severity 'Medium' is due to the nature of the files attempted to be downloaded, which are known for malicious activities. The status is set to 'Closed' because all attempted actions were successfully blocked by the preventive measures in place. The verdict is 'Malicious' based on the Anti-Malware detection of these files. There is no evidence of successful infiltration or execution of malicious software.
#
# 35/71 id:65a4f3a782ed673a196f7bab status:Open->Closed criticality:5->Medium verdict:None->Malicious
# explanation:Anti-Malware detections indicate attempts to download and potentially execute known malicious tools which are typically used for lateral movement or credentials theft, such as Mimikatz. However, all download attempts were successfully blocked by the security measures in place, hence closing the incident.
#
# 36/71 id:65a4f3d782ed673a196f7c07 status:Open->Closed criticality:5->Medium verdict:None->Suspicious
# explanation:The incident involved attempts to download files flagged as malicious by anti-malware systems. However, all actions for downloading these files were successfully blocked, preventing any potential infection. Given that the security measures in place were effective in blocking these attempts, the severity is rated as Medium due to the nature of the threat. The status is closed because of the successful preventative measures. This is classified as a non-malicious event due to successful mitigations already in place.
#
# 37/71 id:65a4f3c882ed673a196f7bf3 status:PendingAnalysis->Closed criticality:6->Medium verdict:None->Malicious
# explanation:The severity is assessed as medium due to the nature of the files involved in the attempted downloads and their potential impact on system security if successful. The status is set to Closed because all attempts were blocked, indicating effective security controls are in place. The verdict is malicious as the files are known malware samples.
#
# 38/71 id:65a4f3d482ed673a196f7c03 status:Open->Closed criticality:6->High verdict:None->Malicious
# explanation:The Anti-Malware engine has flagged multiple outbound download attempts to fetch files known for being used in cyber attacks (such as mimikatz). Due to the nature of the files and the consistency of attempts over a significant period, this poses a potential for successful malware infiltration if not appropriately controlled, hence a 'High' severity and 'Malicious' verdict. Given that all attempts were effectively blocked, closing the incident after internal protocol adjustments is appropriate.
#
# 39/71 id:65a4f3a082ed673a196f7b9d status:Open->Closed criticality:6->Medium verdict:None->Malicious
# explanation:The connection attempts involved downloading files classified as malicious by Anti-Malware mechanisms. Despite the high number of attempted downloads, the threat was effectively neutralized as all observed actions were blocked by the security systems in place. This suggests that while the actions were of malicious intent, they have been controlled, allowing for the incident to be closed.
#
# 40/71 id:65a4f3be82ed673a196f7bdc status:Open->Closed criticality:5->Medium verdict:None->Malicious
# explanation:The incident involves repeated attempts to download files that have been recognized as malicious by the anti-malware engine, such as 'mimikatz_trunk.zip', which is notoriously used for malicious purposes like harvesting passwords. However, since every attempt to access these files was blocked, closing the incident is appropriate. This indicates a robust defensive mechanism in place, which mitigated the potential impact of such threats effectively. Since the attempts to introduce malicious payloads into the network were neutralized immediately, the current security measures seem adequate at this time.
#
# 41/71 id:65a4f3d682ed673a196f7c05 status:Open->Closed criticality:5->High verdict:None->Malicious
# explanation:The threat involved repeated download attempts of known malware, Mimikatz and eicar test files, which have been correctly blocked by the anti-malware system. This indicates a potential threat actor attempting to bypass security measures. The nature of the attempted downloads and the reputation of the files involved warrant a classification of 'Malicious' with a 'High' severity. Given that all attempts were blocked, the incident can be considered contained and therefore closed.
#
# 42/71 id:67c414ca28943b55b769fe43 status:Open->PendingAnalysis criticality:9->High verdict:None->Malicious
# explanation:The incident is marked with high severity due to the communication with validated malicious domains, which indicates possible malware activity. The threat is still open for analysis, requiring further investigation to assess the impact and any additional remediation actions necessary. Given the involvement of known malicious domains, the verdict is malicious.
#
# 43/71 id:67c412d928943b55b769fc65 status:Open->PendingAnalysis criticality:10->High verdict:None->Malicious
# explanation:The communication with malicious domains as identified by a threat intelligence feed indicates a high likelihood of some malware-related activity, warranting a 'High' severity rating. The incident remains 'PendingAnalysis' due to the need for further investigation and confirmation of malicious activity. Given the nature of the communication and its detection by threat intelligence sources, the verdict is 'Malicious'.
#
# 44/71 id:67c45ac628943b55b76a216d status:Open->Monitoring criticality:9->Medium verdict:None->Malicious
# explanation:The communication with domains identified as malicious suggests that the host might be compromised or attempting to connect to malicious entities. The absence of phishing indicators directs the focus toward malware-related activities. The threat is deemed significant enough to warrant a medium severity, and ongoing monitoring is advised to ensure no further suspicious activities occur.
#
# 45/71 id:67c4132b28943b55b769fd36 status:Open->Monitoring criticality:10->High verdict:None->Malicious
# explanation:The incident's high severity is due to the confirmation of communication with domains deemed malicious by threat intelligence feeds. This indicates a significant risk, possibly involving malware or data leakage. The status is set to Monitoring to ensure that any recurrence or escalation can be quickly identified and mitigated. The verdict is Malicious due to the nature of the domains contacted, necessitating immediate investigation and response to prevent potential data breaches or system compromise.
#
# 46/71 id:67c411bf28943b55b769fbb5 status:Open->PendingAnalysis criticality:9->High verdict:None->Malicious
# explanation:The incident describes communication with domains validated as malicious, suggesting a higher severity due to the likelihood of malware presence. The status is set to PendingAnalysis to ensure proper examination of the involved systems for any potential infections. Given the nature of communication with known malicious entities, the verdict is classified as 'Malicious'.
#
# 47/71 id:67c455a628943b55b76a2017 status:Open->Monitoring criticality:6->Medium verdict:None->Malicious
# explanation:This incident involves DNS queries to phishing-related domains, suggesting potential exposure to phishing attacks. The traffic was flagged by threat intelligence feeds and is indicative of malicious activity. Despite no conclusive indication of data breach or compromise, proactive monitoring is necessary to ensure no further suspicious activity transpires. Closing may be considered if further access to these domains is conclusively blocked or deemed harmless upon further investigation.
#
# 48/71 id:67c4552a28943b55b76a1fea status:Open->Closed criticality:6->Medium verdict:None->Malicious
# explanation:This incident involves DNS queries to domains flagged in threat intelligence as linked to phishing, indicating a potentially malicious intent. The severity is medium due to the potential risks associated with phishing. Since these domains are recognized as part of a phishing operation, the verdict is 'Malicious'. The incident is considered 'Closed' as actions can be taken to block future queries without further data needed.
#
# 49/71 id:67c4551428943b55b76a1fdf status:Open->PendingAnalysis criticality:6->Medium verdict:None->Suspicious
# explanation:DNS queries to phishing-related domains are a strong indicator of a potential phishing attack. However, since this activity was flagged by threat intelligence feeds and it is unclear if any action was successful or if a compromise occurred, the incident is classified as Medium severity and requires further analysis to establish the extent of any potential compromise or data exfiltration. The situation is suspicious, and pending analysis will help determine if it should be escalated to malicious or downgraded to benign depending on additional findings.
#
# 50/71 id:67c454d628943b55b76a1fb9 status:Open->Monitoring criticality:6->Medium verdict:None->Suspicious
# explanation:The DNS queries to known phishing-related domains are flagged as suspicious, indicating potential phishing activity. However, since there are no signs of follow-up malicious activities, it has been classified with Medium severity and set to Monitoring status to ensure that no further incidents occur. Blocking attempted access to these domains and educating users represent a proactive way to mitigate potential threats.
#
# 51/71 id:67c4549d28943b55b76a1f8e status:Open->Closed criticality:6->Medium verdict:None->Suspicious
# explanation:The incident involves DNS queries to domains associated with phishing activity, which is a known method for malicious actors to attempt to gain unauthorized access to sensitive information. Given this is a medium severity issue, it is important to confirm that any attempts to connect to these domains have been blocked. Since there is no indication of further malicious activity, the status can be closed after ensuring all proper safeguards are in place and users are informed.
#
# 52/71 id:674b24631459863ad6444f25 status:Open->PendingAnalysis criticality:6->Medium verdict:None->Suspicious
# explanation:The incident relates to DNS queries to domains flagged for phishing, which signifies a potential threat. Hence, it is deemed suspicious and requires further analysis to determine if the traffic is benign or represents a genuine threat. Medium severity is assigned due to the clear association with phishing indicators.
#
# 53/71 id:67c453ec28943b55b76a1ef2 status:Open->Monitoring criticality:6->Medium verdict:None->Suspicious
# explanation:The severity is set to Medium because DNS queries to phishing-related domains could lead to potential security risks if not addressed. They suggest attempted communication with potentially harmful sources. The status is set to Monitoring as this requires ongoing observation to ensure no successful phishing attacks occur and actions are taken to prevent further communication with these domains. The verdict is Suspicious due to the nature of the domains involved, indicating possible preparation for phishing attacks, though no direct malicious activity has been confirmed yet.
#
# 54/71 id:67c453ca28943b55b76a1eda status:Open->PendingAnalysis criticality:6->Medium verdict:None->Suspicious
# explanation:The DNS queries to known phishing domains indicate suspicious activity that needs further analysis. Since this could potentially be a false positive or an actual phishing attempt, a medium severity is assigned with a status of PendingAnalysis to investigate if there are signs of compromise or confirmed attempts to reach malicious sites. The incident cannot be immediately closed without further assessment since it involves phishing indicators.
#
# 55/71 id:67c450c328943b55b76a1ca3 status:Open->PendingAnalysis criticality:6->Medium verdict:None->Suspicious
# explanation:The severity is set to Medium due to the potential risk of users accessing phishing sites, which could lead to credential theft or other malicious activities. The status is pending analysis as further investigation of the source IP and user behavior is necessary to confirm if any users have been compromised. The verdict is suspicious as the activity indicates potential phishing attempts, but no confirmed malicious actions have been detected yet.
#
# 56/71 id:67c44fb028943b55b76a1ba4 status:Open->PendingAnalysis criticality:6->Medium verdict:None->Suspicious
# explanation:The incident involves DNS queries pointing to domains associated with phishing. This is typically indicative of either a device compromised for phishing campaigns or a potential mistake by users attempting to access these domains. Therefore, it is classified as 'suspicious'. Due to the lack of specific malicious activity reports currently, it remains under 'pending analysis' status. Severity is set to medium due to the potential risk of sensitive information leakage if a phishing attack is successful.
#
# 57/71 id:67c44f7a28943b55b76a1b74 status:Open->Monitoring criticality:6->Medium verdict:None->Suspicious
# explanation:The queries to phishing-related domains signal a potential phishing attempt. Given that this incident is classified as a phishing threat and involves a site connection from a potentially vulnerable source without apparent blocking action, it is prudent to continue monitoring these queries to ensure there is no broader compromise or associated malicious activity. The incident is suspicious in nature, warranting a medium severity due to the potential risk of phishing attacks that can lead to more severe breaches if successful.
#
# 58/71 id:67225d76884a8335fefe12dd status:Reopened->Closed criticality:9->High verdict:None->Informational
# explanation:The initial severity of the incident was rated as 'High' due to the potential impact of the CVEs involved, which include remote code execution and authentication bypass. However, since all attempts were successfully blocked and no unauthorized actions were executed, the verdict was revised to 'Informational,' indicating no immediate threat remains. With the IPS blocking all exploit attempts, the status is updated to 'Closed,' reflecting the resolution of the incident. Continued vigilance through monitoring and scheduled system audits is advised to prevent recurrence.
#
# 59/71 id:665cbacbd429a0493be1ecb0 status:Open->PendingAnalysis criticality:4->Medium verdict:None->Suspicious
# explanation:The consistent generation of unusually long DNS queries is often associated with DNS tunneling, a method used for data exfiltration. While no malicious actions have been confirmed, the persistent nature of these queries warrants further analysis to rule out potential threats or confirm benign activity. Given the potential for data exfiltration, a medium severity is appropriate, and the status remains PendingAnalysis pending further investigation.
#
# 60/71 id:67c4325e28943b55b76a1016 status:Open->PendingAnalysis criticality:3->Medium verdict:None->Suspicious
# explanation:The use of a scripting language to communicate with a low-popularity domain is often indicative of malicious activities. However, the verdict is marked as 'Suspicious' and not 'Malicious' due to the lack of direct evidence of malicious activity. Further analysis is recommended to determine if the behavior is benign or truly malicious. The incident has been assigned a 'Medium' severity due to its potential for being part of a larger threat, and the status is set to 'PendingAnalysis' to facilitate further investigation.
#
# 61/71 id:67c4319f28943b55b76a0f87 status:Open->PendingAnalysis criticality:4->Medium verdict:None->Suspicious
# explanation:The use of a scripting language to communicate with a low-popularity domain over HTTP is a common indicator of malicious activity, such as command and control communication or malware infection. However, further analysis is needed to confirm the malicious intent given the current lack of evidence of direct harmful activity. Therefore, the severity is marked as Medium, the status is PendingAnalysis for further investigation, and the verdict is Suspicious.
#
# 62/71 id:67c4319b28943b55b76a0f85 status:Open->PendingAnalysis criticality:3->Medium verdict:None->Suspicious
# explanation:The incident indicates an outbound HTTP connection to a low-reputation domain using a scripting language, which is a common tactic used in malicious activities such as C2 communications. While there isn't enough information to categorize this as definitively malicious, it's suspicious enough to warrant further investigation before considering closure. As the actions haven't been confirmed to be benign or malicious, further analysis is needed to determine the appropriate response.
#
# 63/71 id:67c4277228943b55b76a0a07 status:Open->PendingAnalysis criticality:6->Medium verdict:None->Suspicious
# explanation:The incident involves communication with URLs flagged for low reputation by threat intelligence. Such URLs can host malware or be involved in phishing activities, posing a security risk. While currently marked as suspicious, further investigation is required to determine potential malicious intent or compromise. Pending additional analysis, it's crucial to safeguard the network by monitoring and possibly restricting access to these URLs.
#
# 64/71 id:67c419b728943b55b76a026f status:Open->PendingAnalysis criticality:9->High verdict:None->Malicious
# explanation:The severity is set to High because the incident involves active communication with domains confirmed as malicious, indicating a high likelihood of compromised systems. The status is PendingAnalysis as further steps are necessary to determine the extent of the compromise and mitigate risks. The verdict is Malicious based on the direct correlation to known malicious domains, requiring immediate attention to prevent potential harm.
#
# 65/71 id:6691e4a37436ef19cc2a0945 status:Open->PendingAnalysis criticality:9->High verdict:None->Malicious
# explanation:The severity is marked as High due to communication with verified malicious domains, indicating potential malware activity. The threat is classified as 'Malicious URL Connection' because the domains involved are confirmed malicious. Even though actions might have been taken, a thorough analysis is required, hence the status is 'PendingAnalysis'. The verdict is 'Malicious' because the activity clearly aligns with malware-related behavior.
#
# 66/71 id:6613d4a62db203748ea75c91 status:Open->Closed criticality:5->Medium verdict:None->Malicious
# explanation:The incident involved multiple attempts to download known malware, which indicates a malicious intent. However, all attempts were blocked by the anti-malware system, preventing any potential harm. Given that the blocks were successful, the severity is set to Medium, and the incident status is Closed since no further action is required at this moment.
#
# 67/71 id:6613bc132db203748ea75a05 status:PendingMoreInfo->Closed criticality:5->High verdict:None->Malicious
# explanation:The incident is considered High severity due to the nature of the vulnerabilities being exploited, such as RCE and identified CVEs. Since all the malicious activities were blocked by IPS, the status can be set to Closed. However, it is important to note that the exploit attempts were detected, and vigilance is advised to prevent further exploitation attempts. The incident is determined to be Malicious because it involves active attempts to exploit critical vulnerabilities in a network system.
#
# 68/71 id:6481ee33071fae0462a73a8f status:Reopened->Closed criticality:7->Medium verdict:None->Informational
# explanation:The incident showed attempts of outbound connections to command and control servers by a known malware variant. All these events were successfully blocked, indicating that the security controls in place are effective. Given this and the lack of subsequent malicious activity, the verdict is deemed Informational, and the status is Closed, reflecting the handling of the situation. Severity is set to Medium due to the precautionary concern over a potentially compromised device despite the blocks.
#
# 69/71 id:6613df552db203748ea75d81 status:PendingAnalysis->Closed criticality:8->Low verdict:None->Informational
# explanation:The incident was classified as involving Potentially Unwanted Program (PUP) activity detected over a period, with actions to block it noted in the logs. PUPs are generally not harmful but can be a nuisance and may lead to security risks if not monitored. Given the low severity of the incident and the successful blocking of the activity, the case can be considered informational and closed, with no immediate threat to the system.
#
# 70/71 id:65bd162683ce8b3a23c5edaa status:Open->Closed criticality:9->Medium verdict:None->Suspicious
# explanation:Although the system consistently attempted connections to malicious domains over a significant period, all instances were successfully blocked by DNS protection. This indicates the presence of suspicious but not necessarily harmful activity. Given that connections were blocked, the risk is managed, therefore it doesn't warrant escalation beyond closing the incident with a 'Suspicious' verdict to log the behavior patterns for future reference.
#
# 71/71 id:65b6d3c683ce8b3a23c56460 status:Open->Closed criticality:8->Medium verdict:None->Malicious
# explanation:The incident is deemed 'Medium' severity due to the involvement with multiple domains identified as malicious and the extended activity duration. All access attempts to malicious domains were blocked successfully by DNS Protection, which justifies closing the incident as no current threat is active. Given the nature and the blocked status, it suggests a proactive measure was effective, but review and monitoring should continue to prevent future issues.
#
# PendingAnalysis:25
# Monitoring:8
# Closed:35

# %% [markdown]
# ### Step 3: Submitting the LLM responses as analyst feedback using the Cato API
#
# Our agent will be able to submit feedback, set the severity and threat type and even close XDR incidents using the **analystFeedback** mutation, which is documented here: [https://api.catonetworks.com/documentation/#mutation-xdr.analystFeedback](https://api.catonetworks.com/documentation/#mutation-xdr.analystFeedback). This is a much smaller, simpler call than the XDR stories call the agent used to download the stories. The biggest difficulty we have is in transforming the response from the LLM to fit the Cato API's input parameters, as defined [here](https://api.catonetworks.com/documentation/#definition-AnalystFeedbackInput). However... compare those input parameters with the JSON structure we asked the LLM for in the system prompt, and what do you see... that's right, they are almost the same. By telling the LLM to provide the response using the same fields that the API mutation requires, we have made it very easy for the agent to transform the data from LLM to API.
#
# The only real change is that instead of using the **additionalInfo** field provided by the LLM, I use instead the **explanation** field we asked it for. I found in testing that the additionalInfo was largely redundant, being very similar to the threatType data. I also thought it would be useful for a human analyst to be able to look at a story in the Cato Management Application and see not only that it has been worked by the LLM, but also see an explanation of why the LLM took the decisions which it did.
#
# So all the agent needs to do now is define the query and loop over the saved story analysis results, submitting each one. There is a chance of errors here, if the LLM for whatever reason decided to go off-piste and provide a value for an enum field which isn't part of the enum. We'll print those but otherwise not worry about them too much - all it means is that the story will remain unmodified, so a human analyst will need to take a look at it.

# %%
#
# The analystFeedback mutation call
#
query = '''mutation analystFeedback($accountId: ID!, $input: AnalystFeedbackInput!) {
  xdr(accountId: $accountId) {
    analystFeedback(input: $input) {
      story {
        id
      }
    }
  }
}'''


#
# Iterate over the results, executing the feedback in a mutation call to the Cato API.
#
for story_id, result in results.items():

    #
    # Log the entry
    #
    print(f'Processing id:{story_id} status:{result["status"]}')

    #
    # Map the LLM result to the Cato API input fields
    #
    variables = {
        "accountId": os.environ["CATO_ACCOUNT_ID"],
        "input": {
            "storyId": story_id,
            "additionalInfo": f'AI:{result["explanation"]}',
            "severity": result["severity"],
            "status": result["status"],
            "threatClassification": result["threatClassification"],
            "threatType": result["threatType"],
            "verdict": result["verdict"]
        }
    }

    #
    # Make the API call, reporting any failures
    #
    success, response = C.send("analystFeedback", variables, query)
    if not success:
        print(f'FAILURE {story_id}')
        print(json.dumps(variables, indent=2))
        print(response,"\n\n")
# Out:
# Processing id:66c08a7427f1a81d2bf5080b status:PendingAnalysis
# Processing id:66b04dd163405215b7ddd526 status:PendingAnalysis
# Processing id:67c4271e28943b55b76a09c1 status:PendingAnalysis
# Processing id:67c4270b28943b55b76a09b1 status:Monitoring
# Processing id:67c426e028943b55b76a09a0 status:PendingAnalysis
# Processing id:67c4279d28943b55b76a0a44 status:Closed
# Processing id:67c4278f28943b55b76a0a32 status:PendingAnalysis
# Processing id:67c46a11ddfded5aa324a789 status:Closed
# Processing id:67c427c028943b55b76a0a7f status:Closed
# Processing id:67c4271428943b55b76a09b9 status:Closed
# Processing id:67c4275428943b55b76a09e9 status:Monitoring
# Processing id:67c4273828943b55b76a09d5 status:Closed
# Processing id:67c41b9628943b55b76a033b status:Closed
# Processing id:6565ad05f916b2799c1790b6 status:Closed
# Processing id:67c41f1528943b55b76a0668 status:PendingAnalysis
# Processing id:6565ad04f916b2799c1790b4 status:Closed
# Processing id:6565acf6f916b2799c179099 status:Closed
# Processing id:6565acfef916b2799c1790a8 status:Closed
# Processing id:6565ad00f916b2799c1790ab status:Closed
# Processing id:67c41a4528943b55b76a02b8 status:PendingAnalysis
# Processing id:67c41c0328943b55b76a03b3 status:PendingAnalysis
# Processing id:67c46345ddfded5aa324a640 status:PendingAnalysis
# Processing id:6565acf9f916b2799c17909c status:Closed
# Processing id:6565acf6f916b2799c179097 status:Closed
# Processing id:6565ad0ff916b2799c1790cb status:Closed
# Processing id:6565ad0df916b2799c1790c5 status:Closed
# Processing id:67c4110228943b55b769fab6 status:PendingAnalysis
# Processing id:65a4f3e482ed673a196f7c14 status:Closed
# Processing id:65a4f3ec82ed673a196f7c1c status:Closed
# Processing id:65a4f3ce82ed673a196f7bfe status:Closed
# Processing id:65a4f3e082ed673a196f7c12 status:Closed
# Processing id:65a4f3a782ed673a196f7bab status:Closed
# Processing id:65a4f3d782ed673a196f7c07 status:Closed
# Processing id:65a4f3c882ed673a196f7bf3 status:Closed
# Processing id:65a4f3d482ed673a196f7c03 status:Closed
# Processing id:65a4f3a082ed673a196f7b9d status:Closed
# Processing id:65a4f3be82ed673a196f7bdc status:Closed
# Processing id:65a4f3d682ed673a196f7c05 status:Closed
# Processing id:67c414ca28943b55b769fe43 status:PendingAnalysis
# Processing id:67c412d928943b55b769fc65 status:PendingAnalysis
# Processing id:67c45ac628943b55b76a216d status:Monitoring
# Processing id:67c4132b28943b55b769fd36 status:Monitoring
# Processing id:67c411bf28943b55b769fbb5 status:PendingAnalysis
# Processing id:67c455a628943b55b76a2017 status:Monitoring
# Processing id:67c4552a28943b55b76a1fea status:Closed
# Processing id:67c4551428943b55b76a1fdf status:PendingAnalysis
# Processing id:67c454d628943b55b76a1fb9 status:Monitoring
# Processing id:67c4549d28943b55b76a1f8e status:Closed
# Processing id:674b24631459863ad6444f25 status:PendingAnalysis
# Processing id:67c453ec28943b55b76a1ef2 status:Monitoring
# Processing id:67c453ca28943b55b76a1eda status:PendingAnalysis
# Processing id:67c450c328943b55b76a1ca3 status:PendingAnalysis
# Processing id:67c44fb028943b55b76a1ba4 status:PendingAnalysis
# Processing id:67c44f7a28943b55b76a1b74 status:Monitoring
# Processing id:67225d76884a8335fefe12dd status:Closed
# Processing id:665cbacbd429a0493be1ecb0 status:PendingAnalysis
# Processing id:67c4325e28943b55b76a1016 status:PendingAnalysis
# Processing id:67c4319f28943b55b76a0f87 status:PendingAnalysis
# Processing id:67c4319b28943b55b76a0f85 status:PendingAnalysis
# Processing id:67c4277228943b55b76a0a07 status:PendingAnalysis
# Processing id:67c419b728943b55b76a026f status:PendingAnalysis
# Processing id:6691e4a37436ef19cc2a0945 status:PendingAnalysis
# Processing id:6613d4a62db203748ea75c91 status:Closed
# Processing id:6613bc132db203748ea75a05 status:Closed
# Processing id:6481ee33071fae0462a73a8f status:Closed
# Processing id:6613df552db203748ea75d81 status:Closed
# Processing id:65bd162683ce8b3a23c5edaa status:Closed
# Processing id:65b6d3c683ce8b3a23c56460 status:Closed

# %% [markdown]
# ### Conclusion ###
#
# There you have it, all of the Python code required to create an AI Agent which can use an LLM to triage and manage a Cato customer's XDR story feed. So is it an actual agent? **No, this is not yet an agent.** This is a Jupyter Notebook which is not really suitable for independent execution. As described in the introduction, this is one of the mandatory requirements for something to be called Agentic AI.
#
# So what would be required to turn this into an agent? All you'd need to do is copy the code into a single Python script or module, and then have a way of scheduling that code to run 24x7 with no human intervention. Many customers would use a cloud service such as AWS Lambda or Azure Functions, but it could also be as simple as a cron job running on a Linux VM.
#
# As well as coming up with a suitable platform for continuous operation, someone looking to run an agent such as this in a production environment should probably also consider:
#
# * Tuning the system prompt to better align the recommendations with the organisation's objectives and risk profile. For example, additional examples could be provided.
# * As mentioned, Cato XDR stories are very rich objects with potentially thousands of fields. The larger the object, the higher the token count, the more expensive the LLM cost. Removing some of these fields could result in significant savings without decreasing the quality of the model recommendations. For example, it might not be necessary to send all of the IoAs, timeseries values and incident fields. The company might also decide not to send very large stories to the model for analysis, and instead leave these for human analysts.
# * A way for the Agent to log and report on its actions, to assist with ongoing QA and monitoring.
